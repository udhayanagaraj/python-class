# %% [markdown]
# Set data structure and its methods

# %%
a = "apples"
n = len(a)

n % 26
# Out:
# 6

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
print(thisset[0])
# Out:
# {'apple', 'banana', 'cherry'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 thisset = {"apple", "banana", "cherry"}
#       2 print(thisset)
# ----> 3 print(thisset[0])
#
# TypeError: 'set' object is not subscriptable

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)

# %%
thisset = {"apple", "banana", "cherry", "apple"}
thisset
# Out:
# {'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry",False, True, 0,1,2,3,0.6,101,1111,-1}

print(thisset)
# Out:
# {0, True, 2, 3, 0.6, 101, 'banana', 'apple', 'cherry', 1111, -1}

# %%
0 is False
1 is True

# %%
n = 1
if n:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
s = set((1,3,4,5,6,7))
s
# Out:
# {1, 3, 4, 5, 6, 7}

# %%
type(s)
# Out:
# set

# %%
type(thisset)
# Out:
# set

# %%
x = {1,2}

y = set((1,2))
type(x)
# Out:
# set

# %%
type(y)
# Out:
# set

# %% [markdown]
# Accessing the set elements

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
thisset.add("grape")
thisset
# Out:
# {'apple', 'banana', 'cherry', 'grape'}

# %% [markdown]
# Update method

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

# for x in tropical:
#     thisset.add(x)

# %%
thisset.update(tropical)
thisset
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'papaya', 'pineapple'}

# %%
# Remove method

thisset.remove("cherry")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Remove method
# ----> 3 thisset.remove("cherry")
#
# KeyError: 'cherry'

# %%
thisset.discard("cherry")

# %%
thisset.pop()
# Out:
# 'papaya'

# %%
thisset = {}

# %%
del thisset

# %%
thisset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 thisset
#
# NameError: name 'thisset' is not defined

# %%
# union

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3  = set1.union(set2)
set3
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set1
# Out:
# {'a', 'b', 'c'}

# %%
set2
# Out:
# {1, 2, 3}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
print(set3)
# Out:
# {'a', 1, 'b', 2, 'c', 3}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {'a', 1, 'b', 2, 3, 'John', 'Elena', 'apple', 'cherry', 'c', 'bananas'}

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
# Out:
# frozenset({'apple', 'banana', 'cherry'})
